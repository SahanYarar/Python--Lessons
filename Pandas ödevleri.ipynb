# %%
import pandas as pd

# %%
dataset= pd.read_csv("mls-salaries-2017.csv")

# %%
dataset
# Out:
#     club last_name    first_name position  base_salary  \
# 0    ATL   Almiron        Miguel        M    1912500.0
# 1    ATL   Ambrose         Mikey        D      65625.0
# 2    ATL      Asad         Yamil        M     150000.0
# 3    ATL     Bloom          Mark        D      99225.0
# 4    ATL  Carleton        Andrew        F      65000.0
# ..   ...       ...           ...      ...          ...
# 611  VAN  Tornaghi         Paolo       GK      80000.0
# 612  VAN    Waston       Kendall        D     350000.0
# 613  VAN  Williams       Sheanon        D     175000.0
# 614  NaN   Babouli            Mo        F      54075.0
# 615  NaN    Ramajo  David Mateos        D     420000.0
#
#      guaranteed_compensation
# 0                 2297000.00
# 1                   65625.00
# 2                  150000.00
# 3                  106573.89
# 4                   77400.00
# ..                       ...
# 611                 80000.00
# 612                368125.00
# 613                184000.00
# ...

# %%
dataset[:11]
# Out:
#    club       last_name first_name position  base_salary  \
# 0   ATL         Almiron     Miguel        M    1912500.0
# 1   ATL         Ambrose      Mikey        D      65625.0
# 2   ATL            Asad      Yamil        M     150000.0
# 3   ATL           Bloom       Mark        D      99225.0
# 4   ATL        Carleton     Andrew        F      65000.0
# 5   ATL         Carmona     Carlos        M     675000.0
# 6   ATL           Garza       Greg        D     150000.0
# 7   ATL  Gonzalez Pirez    Leandro        D     250008.0
# 8   ATL          Goslin      Chris        M      70000.0
# 9   ATL         Gressel     Julian        M      75000.0
# 10  ATL           Heath   Harrison        M      66150.0
#
#     guaranteed_compensation
# 0                2297000.00
# 1                  65625.00
# 2                 150000.00
# 3                 106573.89
# 4                  77400.00
# 5                 725000.00
# 6                 150000.00
# 7                 285008.00
# ...

# %%
len(dataset)
# Out:
# 616

# %%
dataset.base_salary.sum()
# Out:
# 182938285.91

# %%
dataset["base_salary"].mean()
# Out:
# 296977.7368668831

# %%
dataset.base_salary.max()
# Out:
# 6660000.0

# %%
dataset.guaranteed_compensation.max()
# Out:
# 7167500.0

# %%
dataset[dataset["guaranteed_compensation"].max() == dataset["guaranteed_compensation"]]
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 401  ORL      Kaka        NaN        M    6660000.0                7167500.0

# %%
dataset[dataset["guaranteed_compensation"].max() == dataset["guaranteed_compensation"]]["last_name"]
# Out:
# 401    Kaka
# Name: last_name, dtype: object

# %%
dataset
# Out:
#     club last_name    first_name position  base_salary  \
# 0    ATL   Almiron        Miguel        M    1912500.0
# 1    ATL   Ambrose         Mikey        D      65625.0
# 2    ATL      Asad         Yamil        M     150000.0
# 3    ATL     Bloom          Mark        D      99225.0
# 4    ATL  Carleton        Andrew        F      65000.0
# ..   ...       ...           ...      ...          ...
# 611  VAN  Tornaghi         Paolo       GK      80000.0
# 612  VAN    Waston       Kendall        D     350000.0
# 613  VAN  Williams       Sheanon        D     175000.0
# 614  NaN   Babouli            Mo        F      54075.0
# 615  NaN    Ramajo  David Mateos        D     420000.0
#
#      guaranteed_compensation
# 0                 2297000.00
# 1                   65625.00
# 2                  150000.00
# 3                  106573.89
# 4                   77400.00
# ..                       ...
# 611                 80000.00
# 612                368125.00
# 613                184000.00
# ...

# %%
dataset[dataset["last_name"] == "Gonzalez Pirez"]["position"].iloc[0]
# Out:
# 'D'

# %%
Pozisyon = dataset.groupby("position")

# %%
Pozisyon.mean()
# Out:
#             base_salary  guaranteed_compensation
# position
# D         166574.093784            179533.184811
# D-M       134930.000000            154328.927857
# F         489588.598349            557437.206514
# F-M       335834.000000            367920.805000
# F/M       125000.000000            131250.000000
# GK        146472.515538            158665.155692
# M         376106.218632            406781.788396
# M-D       219032.250000            230282.250000
# M-F       212975.604211            231104.551579
# M/F       550000.000000            565000.000000

# %%
len(dataset["position"].unique())
# Out:
# 10

# %%
dataset["position"].value_counts()
# Out:
# M      212
# D      185
# F      109
# GK      65
# M-F     19
# D-M     14
# F-M      6
# M-D      4
# M/F      1
# F/M      1
# Name: position, dtype: int64

# %%
dataset["club"].value_counts()
# Out:
# VAN      32
# PHI      31
# ATL      31
# CLB      30
# ORL      30
# SJ       29
# DAL      29
# HOU      28
# NYCFC    28
# NYRB     28
# DC       27
# CHI      27
# LA       27
# MTL      27
# RSL      27
# TOR      27
# POR      27
# MNUFC    27
# COL      26
# KC       26
# SEA      25
# NE       23
# LAFC      2
# Name: club, dtype: int64

# %%
dataset
# Out:
#     club last_name    first_name position  base_salary  \
# 0    ATL   Almiron        Miguel        M    1912500.0
# 1    ATL   Ambrose         Mikey        D      65625.0
# 2    ATL      Asad         Yamil        M     150000.0
# 3    ATL     Bloom          Mark        D      99225.0
# 4    ATL  Carleton        Andrew        F      65000.0
# ..   ...       ...           ...      ...          ...
# 611  VAN  Tornaghi         Paolo       GK      80000.0
# 612  VAN    Waston       Kendall        D     350000.0
# 613  VAN  Williams       Sheanon        D     175000.0
# 614  NaN   Babouli            Mo        F      54075.0
# 615  NaN    Ramajo  David Mateos        D     420000.0
#
#      guaranteed_compensation
# 0                 2297000.00
# 1                   65625.00
# 2                  150000.00
# 3                  106573.89
# 4                   77400.00
# ..                       ...
# 611                 80000.00
# 612                368125.00
# 613                184000.00
# ...

# %%
def son_find(last_name):
    if "son" in last_name.lower():
        return True
    return False
dataset[dataset["last_name"].apply(son_find)]
# Out:
#       club      last_name first_name position  base_salary  \
# 21     ATL       Peterson      Jacob        F    165300.00
# 23     ATL       Robinson      Miles        D    125000.04
# 45     CHI        Johnson     Daniel        M     65004.00
# 48     CHI        Lampson       Matt       GK     76000.00
# 85     CLB        Swanson        Ben        M     85000.00
# 163     DC       Robinson      Jalen        D     69996.00
# 233     LA       Jamieson   Bradford        F     66150.00
# 265  MNUFC          Ibson        NaN        M    200004.00
# 276  MNUFC       Thiesson     Jerome        D    171000.00
# 295    MTL  Jackson-Hamel    Anthony        F     66150.00
# 327     NE         Watson  Je-Vaughn      D-M    150000.00
# 338  NYCFC       Harrison       Jack        M    130000.00
# 341  NYCFC        Johnson       Sean       GK    220008.00
# 400    ORL        Johnson       Will        M    414000.00
# 442    PHI        Simpson        Jay        F    465000.00
# ...

# %%
print("""*************************************************************************************************""")
# Out:
# *************************************************************************************************

# %%
youtube = pd.read_csv("USvideos.csv")

# %%
youtube
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# ...

# %%
youtube.drop(["thumbnail_link","video_id","trending_date","publish_time","thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed"],axis = 1,inplace = True)

# %%
len(youtube)
# Out:
# 23362

# %%
len(youtube.columns)
# Out:
# 9

# %%
youtube
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
youtube["likes"].mean()
# Out:
# 45085.35972947522

# %%
youtube["dislikes"].mean()
# Out:
# 2809.7094426847016

# %%
youtube["views"].max()
# Out:
# 149376127

# %%
youtube[youtube["views"].max() ==youtube["views"]]["title"].iloc[0]
# Out:
# 'YouTube Rewind: The Shape of 2017 | #YouTubeRewind'

# %%
youtube.groupby("category_id").mean()[["comment_count"]]
# Out:
#              comment_count
# category_id
# 1              6003.651813
# 2              1730.438235
# 10            10383.559418
# 15             2474.376054
# 17             3256.199515
# 19             1833.011450
# 20             7578.383607
# 22             4491.865854
# 23             5432.868554
# 24             7178.388176
# 25             1523.749869
# 26             4992.165997
# 27             2143.574850
# 28             3350.945159
# 29           100071.562500
# 43             1340.375000

# %%
youtube
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...

# %%
youtube["category_id"].value_counts()
# Out:
# 24    5379
# 10    3366
# 26    2241
# 23    1978
# 25    1907
# 22    1886
# 28    1477
# 1     1324
# 17    1238
# 27    1002
# 15     593
# 2      340
# 20     305
# 19     262
# 29      48
# 43      16
# Name: category_id, dtype: int64

# %%
def countTitleCount(title):
    return len(title)
youtube["title_length"] = youtube["title"].apply(countTitleCount)

# %%
youtube
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id  \
# 0                 CaseyNeistat           22
# 1              LastWeekTonight           24
# 2                 Rudy Mancuso           23
# 3        Good Mythical Morning           24
# 4                     nigahiga           24
# ...
